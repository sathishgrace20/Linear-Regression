# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['poly', 'rbf', 'sigmoid'], 'gamma':['scale','auto'],'C':[10,100,1000,2000,3000]}
grid=GridSearchCV(SVR(), param_grid, n_jobs=-1, refit=True, verbose=3)

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\sathi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.067235      0.005355         0.014312        0.003980       10
# 1        0.088510      0.007349         0.044045        0.007733       10
# 2        0.108563      0.006996         0.024892        0.003809       10
# 3     2327.425299    437.036535         0.023212        0.005361       10
# 4        0.099167      0.005313         0.045912        0.001466       10
# 5        0.063880      0.002376         0.012544        0.000260       10
# 6        0.072605      0.001781         0.012304        0.000750      100
# 7        0.080655      0.002051         0.043006        0.001378      100
# 8        0.105325      0.014724         0.021609        0.000971      100
# 9     3947.902583   2252.814331         0.029336        0.002856      100
# 10       0.173661      0.003521         0.083010        0.002386      100
# 11       0.113203      0.003470         0.022606        0.000737      100
# ...

# %%
age_input=float(input("Age="))
bmi_input=float(input("BMI="))
Children_input=int(input("Children="))
sex_male_input=int(input("Sex_Male, 1 or 0"))
smoke_yes_input=int(input("Smoke_Yes, 1 or 0"))
# Out:
# Age= 45
# BMI= 29
# Children= 2
# Sex_Male, 1 or 0 1
# Smoke_Yes, 1 or 0 0

# %%
Regressor=grid.predict([[age_input,bmi_input,Children_input,sex_male_input,smoke_yes_input]])
# Out:
# C:\Users\sathi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
Regressor
# Out:
# array([8045.48711436])
